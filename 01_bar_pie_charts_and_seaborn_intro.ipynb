# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'malgun gothic'
df = pd.read_csv("./data/supply.csv")
df
# Out:
#     구분      가격  판매량
# 0  고급형  480000   35
# 1  일반형  250000   28
# 2  저가형  180000   22

# %%
label = ['고급형','일반형','저가형']
index = np.arange(len(label))
colors = ['r', 'g', 'b']
plt.bar(index, df['가격'], width=0.5, color = colors, edgecolor = 'purple', alpha=0.3)
plt.title("판매량 집계", fontsize=18, color='r')
plt.xlabel("구분", fontsize=10, color = 'b')
plt.ylabel("가격", fontsize=10)
plt.xticks(index, label, fontsize=12, rotation = 90)
plt.grid()
plt.show()

# %%
y = np.arange(len(label))
plt.barh(y,df['가격'], color = "g", alpha = 0.3, edgecolor = 'r')
plt.yticks(y, label)
#plt.set_xlabel("금액")
#plt.set_ylabel("index")
#plt.set_title("그래프", loc="left")
plt.title("판매량")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['font.family'] = 'malgun gothic'
df = pd.read_csv("./data/supply.csv")
df[['구분','가격']]
label = ['고급형','일반형','저가형']
plt.pie(df['가격'], labels = label, autopct="%.1f%%")
plt.title("판매량 집계", fontsize = 18)
fig = plt.gcf()

plt.savefig("./images/supply.png", dpi = fig.dpi)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os 
plt.rcParams['font.family'] = 'malgun gothic'
df = pd.read_csv("./data/supply.csv")
label = ['고급형','일반형','저가형']
color = ['b','y','r']
x = np.arange(len(label))
plt.bar(x, df['가격'], width=0.5, color = color, edgecolor = 'g', linewidth=3)
plt.title("판매량 집계", fontsize=15, color = 'r')
plt.xlabel("구분", fontsize=11, color = 'r')
plt.xticks(x,label, fontsize=15, rotation = 90)
plt.ylabel("가격", fontsize=11, color = 'r')
fig = plt.gcf()
plt.draw()
plt.savefig("./images/supply2.png", dpi = fig.dpi)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'malgun gothic'
df = sns.load_dataset("tips")
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_theme(style="whitegrid")
sns.barplot(x="day", y = "total_bill", data=df)
plt.show()

# %%
sns.set_theme(style="dark")
sns.barplot(x="sex", y = "total_bill", data = df, errwidth=0)
plt.show()
# Out:
# /tmp/ipykernel_7948/1271843460.py:2: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0}` instead.
#
#   sns.barplot(x="sex", y = "total_bill", data = df, errwidth=0)

# %%
sns.set_theme(style="dark")
sns.barplot(x="total_bill", y = "day", data= df, orient="h", errwidth=0)
plt.show()
# Out:
# /tmp/ipykernel_7948/3967104546.py:2: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0}` instead.
#
#   sns.barplot(x="total_bill", y = "day", data= df, orient="h", errwidth=0)

# %%
sns.set_theme(style="darkgrid")
sns.barplot(x="total_bill", y= "day", data = df, orient="h", palette="coolwarm", errwidth=0)
plt.show()
# Out:
# /tmp/ipykernel_7948/829089905.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="total_bill", y= "day", data = df, orient="h", palette="coolwarm", errwidth=0)
# /tmp/ipykernel_7948/829089905.py:2: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0}` instead.
#
#   sns.barplot(x="total_bill", y= "day", data = df, orient="h", palette="coolwarm", errwidth=0)

# %%
sns.set_theme(style="white")
sns.catplot(x="sex", y = "total_bill", data = df, kind="bar", errwidth =0, palette="coolwarm")
plt.show()
# Out:
# /tmp/ipykernel_7948/2964000318.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="sex", y = "total_bill", data = df, kind="bar", errwidth =0, palette="coolwarm")
# /tmp/ipykernel_7948/2964000318.py:2: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0}` instead.
#
#   sns.catplot(x="sex", y = "total_bill", data = df, kind="bar", errwidth =0, palette="coolwarm")

# %%
sns.catplot(x="sex", y = "total_bill", data = df, kind="bar", hue="smoker", errwidth=0)
plt.show()
# Out:
# /tmp/ipykernel_7948/3523448438.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0}` instead.
#
#   sns.catplot(x="sex", y = "total_bill", data = df, kind="bar", hue="smoker", errwidth=0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'malgun gothic'
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.set_style("whitegrid")
sns.countplot(x="class", hue="who", data = df)
plt.title("타이타닉 등급 승객", fontsize=18)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 45769 (\N{HANGUL SYLLABLE NIG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 44553 (\N{HANGUL SYLLABLE GEUB}) missing from font(s) DejaVu Sans.
# ...

# %%
plt.figure(figsize=(8,6))
sns.violinplot(x=df['who'], y=df['fare'])
plt.title("sex fare", color = 'r')
plt.show()

# %%
df_size= df.pivot_table(index="class", columns="sex", aggfunc="size")
df_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(df_size, annot=True, cmap="RdYlGn", fmt="d", annot_kws={'size':15}, vmin=100, vmax=500, linewidth=5)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'malgun gothic'

iris_df = sns.load_dataset("iris")
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data = iris_df, kind="scatter")
plt.suptitle("꽃받침 length and width", y = 1.05, fontsize=18, color = "r")
plt.show()

# %%
# %matplotlib inline
fg = sns.FacetGrid(data=iris_df, col="species")
fg.map(plt.hist, 'sepal_length')
plt.show()

# %%
sns.pairplot(iris_df, hue="species")
plt.title("Types of iris", fontsize=18)
plt.show()

# %%
pg = sns.PairGrid(iris_df[["sepal_length", "sepal_width", "petal_length", "petal_width"]])
pg.map(sns.scatterplot, color = 'y', alpha = 0.3)
plt.title("Types of iris", fontsize=18)
plt.show()

# %%
pg= sns.PairGrid(iris_df[['sepal_length', 'sepal_width','petal_length','petal_width']])
pg.map_upper(sns.kdeplot, color="green")
pg.map_lower(sns.scatterplot, color = "r", alpha = 0.3)
pg.map_diag(sns.histplot, color = "k", alpha = 0.4)
plt.title("Types of iris", fontsize=18)
plt.show()

# %%
<seaborn>의 그래프 종류!
1. barplot
2. barplot인데 orient="h"로 수평 막대 그래프
3. catplot - 요소별 데이터 비교 hue="분리할 요소" #카테고리 별 분류
4. countplot -  카테고리 별 데이터 항목 개수
5. violinplot- 데이터의 최솟값과 최댓값
6. heatmap - 2차원 테이블(pivot테이블)활용해서 정보 색상 표시 - 상관관계 대한 분포도 표시, 값이 클수록 진하게 
7. jointplot -scatter와 bar 합쳐서 그래프 나타낼 때 kind 옵션으로 데이터 모양 바꾸기 가능
8. FaceGrid - 행, 열 방향으로 서로 다른 조건 적용하여 여러개 그래프(서브플롯 그래프)/ 서브플롯에 적용할 그래프 종류는 map()함수로 
9. pairplot - 3차원 이상의 데이터 그래프로 표혀할 때, 숫자형 데이터에 대해서만 가능, 컬럼 간의 관계를 그래프로 
              map_upper(), map_lower(), map_diag()함수로 대각선 기준 위, 아래, 중심의 그래프 지정 가능
# Out:
#   Cell In[24], line 1
#     <seaborn>의 그래프 종류!
#     ^
# SyntaxError: invalid syntax
