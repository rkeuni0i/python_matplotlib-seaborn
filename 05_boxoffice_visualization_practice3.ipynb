# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("./data/KOBIS_역대_박스오피스.csv", encoding="utf-8")
df.head()
# Out:
#    순위        영화명         개봉일           매출액       관객수  스크린수 대표국적  국적  \
# 0   1         명량  2014-07-30  1.357484e+11  17613682  1587   한국  한국
# 1   2       극한직업  2019-01-23  1.396480e+11  16264944  1978   한국  한국
# 2   3  신과함께-죄와 벌  2017-12-20  1.156987e+11  14410754  1912   한국  한국
# 3   4       국제시장  2014-12-17  1.109135e+11  14257115   966   한국  한국
# 4   5        베테랑  2015-08-05  1.051682e+11  13414009  1064   한국  한국
#
#              배급사
# 0      (주)씨제이이엔엠
# 1      (주)씨제이이엔엠
# 2  롯데쇼핑㈜롯데엔터테인먼트
# 3      (주)씨제이이엔엠
# 4      (주)씨제이이엔엠

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      500 non-null    int64
#  1   영화명     500 non-null    str
#  2   개봉일     500 non-null    str
#  3   매출액     490 non-null    float64
#  4   관객수     500 non-null    int64
#  5   스크린수    500 non-null    int64
#  6   대표국적    500 non-null    str
#  7   국적      500 non-null    str
#  8   배급사     496 non-null    str
# dtypes: float64(1), int64(3), str(5)
# memory usage: 35.3 KB

# %%
df.isnull().sum()
# Out:
# 순위       0
# 영화명      0
# 개봉일      0
# 매출액     10
# 관객수      0
# 스크린수     0
# 대표국적     0
# 국적       0
# 배급사      4
# dtype: int64

# %%
rate = (df['배급사'].isnull().sum() / df['매출액'].shape[0])*100
rate
# Out:
# np.float64(0.8)

# %%
df2= df.copy()
df.isnull().sum()
# Out:
# 순위       0
# 영화명      0
# 개봉일      0
# 매출액     10
# 관객수      0
# 스크린수     0
# 대표국적     0
# 국적       0
# 배급사      4
# dtype: int64

# %%
df2.head()
# Out:
#    순위        영화명         개봉일           매출액       관객수  스크린수 대표국적  국적  \
# 0   1         명량  2014-07-30  1.357484e+11  17613682  1587   한국  한국
# 1   2       극한직업  2019-01-23  1.396480e+11  16264944  1978   한국  한국
# 2   3  신과함께-죄와 벌  2017-12-20  1.156987e+11  14410754  1912   한국  한국
# 3   4       국제시장  2014-12-17  1.109135e+11  14257115   966   한국  한국
# 4   5        베테랑  2015-08-05  1.051682e+11  13414009  1064   한국  한국
#
#              배급사
# 0      (주)씨제이이엔엠
# 1      (주)씨제이이엔엠
# 2  롯데쇼핑㈜롯데엔터테인먼트
# 3      (주)씨제이이엔엠
# 4      (주)씨제이이엔엠

# %%
df2.drop('대표국적',axis=1, inplace=True)
df2
# Out:
#       순위        영화명         개봉일           매출액       관객수  스크린수  국적  \
# 0      1         명량  2014-07-30  1.357484e+11  17613682  1587  한국
# 1      2       극한직업  2019-01-23  1.396480e+11  16264944  1978  한국
# 2      3  신과함께-죄와 벌  2017-12-20  1.156987e+11  14410754  1912  한국
# 3      4       국제시장  2014-12-17  1.109135e+11  14257115   966  한국
# 4      5        베테랑  2015-08-05  1.051682e+11  13414009  1064  한국
# ..   ...        ...         ...           ...       ...   ...  ..
# 495  496      비공식작전  2023-08-02  1.019214e+10   1058645  1151  한국
# 496  497       남극일기  2005-05-19  0.000000e+00   1057311    78  한국
# 497  498        동창생  2013-11-06  7.010197e+09   1048280   660  한국
# 498  499        시크릿  2009-12-03  7.979592e+09   1046787   397  한국
# 499  500       그놈이다  2015-10-28  8.098811e+09   1046313   681  한국
#
#                배급사
# 0        (주)씨제이이엔엠
# 1        (주)씨제이이엔엠
# 2    롯데쇼핑㈜롯데엔터테인먼트
# 3        (주)씨제이이엔엠
# 4        (주)씨제이이엔엠
# ..             ...
# 495         (주)쇼박스
# ...

# %%
df2.dropna(subset=['배급사'], inplace=True)
df2
# Out:
#       순위        영화명         개봉일           매출액       관객수  스크린수  국적  \
# 0      1         명량  2014-07-30  1.357484e+11  17613682  1587  한국
# 1      2       극한직업  2019-01-23  1.396480e+11  16264944  1978  한국
# 2      3  신과함께-죄와 벌  2017-12-20  1.156987e+11  14410754  1912  한국
# 3      4       국제시장  2014-12-17  1.109135e+11  14257115   966  한국
# 4      5        베테랑  2015-08-05  1.051682e+11  13414009  1064  한국
# ..   ...        ...         ...           ...       ...   ...  ..
# 495  496      비공식작전  2023-08-02  1.019214e+10   1058645  1151  한국
# 496  497       남극일기  2005-05-19  0.000000e+00   1057311    78  한국
# 497  498        동창생  2013-11-06  7.010197e+09   1048280   660  한국
# 498  499        시크릿  2009-12-03  7.979592e+09   1046787   397  한국
# 499  500       그놈이다  2015-10-28  8.098811e+09   1046313   681  한국
#
#                배급사
# 0        (주)씨제이이엔엠
# 1        (주)씨제이이엔엠
# 2    롯데쇼핑㈜롯데엔터테인먼트
# 3        (주)씨제이이엔엠
# 4        (주)씨제이이엔엠
# ..             ...
# 495         (주)쇼박스
# ...

# %%
df2.isnull().sum()
df2['매출액'].fillna(0, inplace=True)
df2.isnull().sum()
# Out:
# /tmp/ipykernel_8038/2483202696.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df2['매출액'].fillna(0, inplace=True)
# 순위       0
# 영화명      0
# 개봉일      0
# 매출액     10
# 관객수      0
# 스크린수     0
# 국적       0
# 배급사      0
# dtype: int64

# %%
product = df2.groupby(['배급사']).sum()
product.sort_values(by='스크린수', ascending=False).head()
# Out:
#                         순위                                                영화명  \
# 배급사
# (주)씨제이이엔엠            18682  명량극한직업국제시장베테랑광해, 왕이 된 남자기생충엑시트설국열차수상한 그녀공조히말라야...
# (주)쇼박스               19672  괴물도둑들암살택시운전사파묘검사외전관상국가대표디워웰컴 투 동막골터널내부자들럭키은밀하게...
# (주)넥스트엔터테인먼트월드(NEW)  12793  7번방의 선물부산행변호인연평해전숨바꼭질감시자들안시성더 킹밀수독전바람과 함께 사라지다...
# 롯데컬처웍스(주)롯데엔터테인먼트     4247  신과함께-인과 연한산: 용의 출현완벽한 타인파일럿콘크리트 유토피아82년생 김지영모가...
# 롯데쇼핑㈜롯데엔터테인먼트        11283  신과함께-죄와 벌해적: 바다로 간 산적과속스캔들최종병기 활청년경찰덕혜옹주더 테러 라...
#
#                                                                    개봉일  \
# 배급사
# (주)씨제이이엔엠            2014-07-302019-01-232014-12-172015-08-052012-0...
# (주)쇼박스               2006-07-272012-07-252015-07-222017-08-022024-0...
# (주)넥스트엔터테인먼트월드(NEW)  2013-01-232016-07-202013-12-182015-06-242013-0...
# 롯데컬처웍스(주)롯데엔터테인먼트    2018-08-012022-07-272018-10-312024-07-312023-0...
# 롯데쇼핑㈜롯데엔터테인먼트        2017-12-202014-08-062008-12-032011-08-102017-0...
#
#                               매출액        관객수   스크린수  \
# ...

# %%
product[product['스크린수'] >=30000]
# Out:
#                         순위                                                영화명  \
# 배급사
# (주)넥스트엔터테인먼트월드(NEW)  12793  7번방의 선물부산행변호인연평해전숨바꼭질감시자들안시성더 킹밀수독전바람과 함께 사라지다...
# (주)쇼박스               19672  괴물도둑들암살택시운전사파묘검사외전관상국가대표디워웰컴 투 동막골터널내부자들럭키은밀하게...
# (주)씨제이이엔엠            18682  명량극한직업국제시장베테랑광해, 왕이 된 남자기생충엑시트설국열차수상한 그녀공조히말라야...
#
#                                                                    개봉일  \
# 배급사
# (주)넥스트엔터테인먼트월드(NEW)  2013-01-232016-07-202013-12-182015-06-242013-0...
# (주)쇼박스               2006-07-272012-07-252015-07-222017-08-022024-0...
# (주)씨제이이엔엠            2014-07-302019-01-232014-12-172015-08-052012-0...
#
#                               매출액        관객수   스크린수  \
# 배급사
# (주)넥스트엔터테인먼트월드(NEW)  1.361361e+12  172061923  51181
# (주)쇼박스               1.903165e+12  335279803  61542
# (주)씨제이이엔엠            2.797282e+12  357136172  88373
#
#                                                                     국적
# 배급사
# ...

# %%
product = product.sort_values(by='관객수', ascending=False)
product.head(1)
# Out:
#               순위                                                영화명  \
# 배급사
# (주)씨제이이엔엠  18682  명량극한직업국제시장베테랑광해, 왕이 된 남자기생충엑시트설국열차수상한 그녀공조히말라야...
#
#                                                          개봉일           매출액  \
# 배급사
# (주)씨제이이엔엠  2014-07-302019-01-232014-12-172015-08-052012-0...  2.797282e+12
#
#                  관객수   스크린수                                                 국적
# 배급사
# (주)씨제이이엔엠  357136172  88373  한국한국한국한국한국한국한국한국,체코한국한국한국한국한국한국한국,독일한국한국한국한국한국...

# %%
df2['스크린수_cut'] = pd.cut(df2['스크린수'],bins=10)
df2['스크린수_cut'].value_counts()
# Out:
# 스크린수_cut
# (-2.98, 298.0]      141
# (298.0, 596.0]       94
# (596.0, 894.0]       94
# (894.0, 1192.0]      72
# (1192.0, 1490.0]     45
# (1490.0, 1788.0]     23
# (1788.0, 2086.0]     14
# (2086.0, 2384.0]      7
# (2384.0, 2682.0]      4
# (2682.0, 2980.0]      2
# Name: count, dtype: int64

# %%
df2['스크린수_qcut'] = pd.qcut(df2['스크린수'], q = 10)
df2['스크린수_qcut'].value_counts()
# Out:
# 스크린수_qcut
# (-0.001, 55.0]      52
# (350.5, 512.0]      50
# (620.0, 785.0]      50
# (974.0, 1176.0]     50
# (1493.5, 2980.0]    50
# (55.0, 82.0]        49
# (512.0, 620.0]      49
# (785.0, 974.0]      49
# (1176.0, 1493.5]    49
# (82.0, 350.5]       48
# Name: count, dtype: int64

# %%
plt.rcParams['font.family'] = 'malgun gothic'
plt.figure(figsize=(14,10))
product.head().스크린수[:].plot(kind="bar", rot=0)
plt.xlabel("영화배급사", fontsize=18)
plt.ylabel("스크린수", fontsize=18)
plt.title("흥행 영화 순위 Top5", color = "green")
plt.show()

# %%
plt.figure(figsize=(14,10))
plt.plot(product.head().스크린수[:], color="blue")
plt.xlabel("영화배급사",fontsize=18)
plt.ylabel("스크린수",fontsize=18)
plt.title("흥행 영화 순위 Top5", color = "green")
plt.show()

# %%
df = pd.read_csv("./data/it_product.csv", encoding="utf-8")
df.head()
# Out:
#   product  price  year
# 0   mouse  22000  2021
# 1   mouse  27000  2022
# 2     usb  25000  2022
# 3     usb  29000  2022
# 4     usb  35000  2023

# %%
group = df.groupby('product').sum()
group = group.sort_values(by="price", ascending=True)
group.drop(['year'], axis=1, inplace=True)

plt.figure(figsize=(8,5))
sns.barplot(x = group.index, y = group.price, data = group, color = "skyblue", hatch="/", edgecolor = "g")
sns.lineplot(x = group.index, y = group.price, data = group, color="red",linestyle = "--", marker="o", markeredgecolor = 'b')
plt.xlabel("product", fontsize=20)
plt.ylabel("가격", fontsize=18)
plt.title("제품별 총액", fontsize=20, color="g")
plt.show()
